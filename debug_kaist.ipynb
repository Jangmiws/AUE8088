# %% [markdown]
# # Jupyter notebook for debugging

# %%
# %load_ext autoreload
# %autoreload 2

# Copied from `train` function in train_simple.py:L78
import yaml

device = 'cuda'
hyp = 'data/hyps/hyp.no-augmentation.yaml'

with open(hyp, errors="ignore") as f:
    hyp = yaml.safe_load(f)  # load hyps dict

# %%
from models.yolo import Model
from utils.general import check_dataset

cfg = 'models/yolov5n_kaist-rgbt.yaml'
data = 'data/kaist-rgbt.yaml'
data_dict = check_dataset(data)

nc = int(data_dict["nc"])  # number of classes
model = Model(cfg, ch=3, nc=nc, anchors=hyp.get("anchors")).to(device)  # create
# Out:
# Overriding model.yaml nc=1 with nc=4
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.MultiStreamConv           [3, 16, 6, 2, 2]
#   1                -1  1      9344  models.common.MultiStreamConv           [16, 32, 3, 2]
#   2                -1  1      9600  models.common.MultiStreamC3             [32, 32, 1]
#   3                -1  1         0  models.common.Fusion                    ['concat', 2]
#   4                -1  1      4224  models.common.Conv                      [64, 64, 1, 1]
#   5                -1  1     36992  models.common.Conv                      [64, 64, 3, 2]
#   6                -1  2     29184  models.common.C3                        [64, 64, 2]
#   7                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   8                -1  3    156928  models.common.C3                        [128, 128, 3]
#   9                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#  10                -1  1    296448  models.common.C3                        [256, 256, 1]
#  11                -1  1    164608  models.common.SPPF                      [256, 256, 5]
#  12                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 7]  1         0  models.common.Concat                    [1]
#  15                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  16                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#  17                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  18           [-1, 5]  1         0  models.common.Concat                    [1]
#  19                -1  1     22912  models.common.C3                        [128, 64, 1, False]
#  20                -1  1     36992  models.common.Conv                      [64, 64, 3, 2]
#  21          [-1, 15]  1         0  models.common.Concat                    [1]
#  22                -1  1     82688  models.common.C3                        [192, 128, 1, False]
#  23                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  24          [-1, 11]  1         0  models.common.Concat                    [1]
#  25                -1  1    329216  models.common.C3                        [384, 256, 1, False]
#  26      [19, 22, 25]  1     12177  models.yolo.Detect                      [4, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [64, 128, 256]]
# YOLOv5n_kaist-rgbt summary: 248 layers, 1844177 parameters, 1844177 gradients

# %%
anchors = model.model[-1].anchors

# [TODO] Draw anchors

# %% [markdown]
# ## Sanity check: dataset
# - Read images and label
# - Visualize bounding boxes

# %%
import cv2
import os
import numpy as np
from PIL import Image

annFile = 'datasets/kaist-rgbt/train/labels/set05_V000_I01219.txt'
lwirFile = annFile.replace('labels', 'images/lwir').replace('.txt', '.jpg')
visFile  = annFile.replace('labels', 'images/visible').replace('.txt', '.jpg')

# Read images
img_lwir = cv2.imread(lwirFile)
img_vis  = cv2.imread(visFile)

h, w = img_vis.shape[:2]

# Read labels
with open(annFile, 'r') as fp:
    labels = [x.split() for x in fp.read().strip().splitlines() if len(x)]

colors = {
    0: (255, 0, 0),
    1: (0, 255, 0),
    2: (0, 0, 255),
    3: (255, 0, 255),
}

if len(labels):
    # convert normalized bbox to pixel coordinates
    labels = np.array(labels, dtype=np.float32)
    labels[:, (1, 3)] *= w
    labels[:, (2, 4)] *= h

    cls = labels[:, 0]

    xyxy = np.zeros((len(labels), 4))
    xyxy[:, :2] = labels[:, 1:3]
    xyxy[:, 2:] = labels[:, 1:3] + labels[:, 3:5]
    xyxy = xyxy.astype(np.int16)

    for c, bb in zip(cls, xyxy):
        color = colors[c]
        cv2.rectangle(img_lwir, bb[:2], bb[2:], color)
        cv2.rectangle(img_vis,  bb[:2], bb[2:], color)

images = np.concatenate([img_lwir, img_vis], axis=1)
Image.fromarray(images)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x512>

# %% [markdown]
# ## Sanity check: dataset class
# - Visualize bounding boxes from dataset class

# %%
from utils.dataloaders import create_dataloader
from utils.general import check_img_size, colorstr

imgsz = 640
batch_size = 1
single_cls = False
seed = 0

train_path = data_dict["train"]
gs = max(int(model.stride.max()), 32)  # grid size (max stride)
imgsz = check_img_size(imgsz, gs, floor=gs * 2)  # verify imgsz is gs-multiple

train_loader, dataset = create_dataloader(
    train_path,
    imgsz,
    batch_size,
    gs,
    single_cls,
    hyp=hyp,
    augment=False,      # TODO: check if there is no bug when applying augmentation
    cache=None,
    rect=False,
    rank=-1,
    workers=8,
    image_weights=False,
    quad=False,
    prefix=colorstr("train: "),
    shuffle=False,      # No shuffle for debugging
    seed=seed,
    rgbt_input=True,
)
# Out:
# train: Scanning /home/jys/class/kaist-rgbt/my_train.cache... 10030 images, 5629 backgrounds, 0 corrupt: 100%|██████████| 10030/10030 [00:00<?, ?it/s]

# %%
from utils.dataloaders import LoadRGBTImagesAndLabels
from utils.general import xywh2xyxy

frame = 300

# Get a minibatch
# for ii, (imgs, targets, paths, _) in enumerate(train_loader):
#     break

# Get a minibatch (fast)
imgs, targets, paths, shapes, _ = LoadRGBTImagesAndLabels.collate_fn([dataset[frame]])

idx = 0
img_lwir = imgs[0][idx].numpy().transpose((1, 2, 0))
img_vis  = imgs[1][idx].numpy().transpose((1, 2, 0))
h, w = img_vis.shape[:2]

labels = targets.numpy()

colors = {
    0: (255, 0, 0),
    1: (0, 255, 0),
    2: (0, 0, 255),
    3: (255, 0, 255),
}

if len(labels):
    labels = labels[labels[:, 0] == idx, 1:]

    # convert normalized bbox to pixel coordinates
    labels = np.array(labels, dtype=np.float32)
    labels[:, (1, 3)] *= w
    labels[:, (2, 4)] *= h

    cls = labels[:, 0]

    xyxy = xywh2xyxy(labels[:, 1:5])
    xyxy = xyxy.astype(np.int16)

    img_lwir = np.ascontiguousarray(img_lwir)
    img_vis = np.ascontiguousarray(img_vis)

    for c, bb in zip(cls, xyxy):
        color = colors[c]
        cv2.rectangle(img_lwir, bb[:2], bb[2:], color)
        cv2.rectangle(img_vis,  bb[:2], bb[2:], color)

images = np.concatenate([img_lwir, img_vis], axis=1)
print(paths[idx])
Image.fromarray(images)
# Out:
# datasets/kaist-rgbt/train/images/{}/set00_V000_I01415.jpg
# <PIL.Image.Image image mode=RGB size=1280x640>

# %% [markdown]
# ## Run trained model
# - Visualize bounding boxes from dataset class

# %%
import torch
from models.yolo import Model
from utils.torch_utils import select_device

weights = 'kaist-rgbt_best.pt'      # Train your own model!
data = 'data/kaist-rgbt.yaml'
cfg = 'models/yolov5s_kaist-rgbt.yaml'
hyp = 'data/hyps/hyp.scratch-low.yaml'
nc = 1
half = False  # use FP16 half-precision inference
dnn = False  # use OpenCV DNN for ONNX inference
device = select_device('cpu')

with open(hyp, errors="ignore") as f:
    hyp = yaml.safe_load(f)  # load hyps dict

model = Model(cfg, ch=3, nc=nc, anchors=hyp.get("anchors")).to(device)  # create

# inference
model.eval()
ims = [im.to(device, non_blocking=True).float() / 255 for im in imgs]    # For RGB-T input
with torch.no_grad():
    pred = model(ims)  # forward
# Out:
# YOLOv5 🚀 bddaf3c Python-3.10.0 torch-2.7.0+cu126 CPU
#
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.MultiStreamConv           [3, 32, 6, 2, 2]
#   1                -1  1     37120  models.common.MultiStreamConv           [32, 64, 3, 2]
#   2                -1  1     37632  models.common.MultiStreamC3             [64, 64, 1]
#   3                -1  1         0  models.common.Fusion                    ['concat', 2]
#   4                -1  1     16640  models.common.Conv                      [128, 128, 1, 1]
#   5                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#   6                -1  2    115712  models.common.C3                        [128, 128, 2]
#   7                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   8                -1  3    625152  models.common.C3                        [256, 256, 3]
#   9                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#  10                -1  1   1182720  models.common.C3                        [512, 512, 1]
#  11                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  12                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 7]  1         0  models.common.Concat                    [1]
#  15                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  16                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  17                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  18           [-1, 5]  1         0  models.common.Concat                    [1]
#  19                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  20                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  21          [-1, 15]  1         0  models.common.Concat                    [1]
#  22                -1  1    329216  models.common.C3                        [384, 256, 1, False]
#  23                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  24          [-1, 11]  1         0  models.common.Concat                    [1]
#  25                -1  1   1313792  models.common.C3                        [768, 512, 1, False]
#  26      [19, 22, 25]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# YOLOv5s_kaist-rgbt summary: 248 layers, 7317430 parameters, 7317430 gradients

# %%
#[TODO] anchor 조정

from utils.autoanchor import kmean_anchors

n_anchors = 9 

# k-means 알고리즘을 실행하여 최적의 앵커
new_anchors = kmean_anchors(dataset, n=n_anchors, img_size=imgsz, thr=4.0, gen=1000, verbose=True)

print("\n\nCalculated new anchors:\n", new_anchors)
# Out:
# AutoAnchor: Running kmeans for 9 anchors on 10533 points...
#   0%|          | 0/1000 [00:00<?, ?it/s]AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.11 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.480/0.859-mean/best, past_thr=0.561-mean: 25,41, 24,56, 35,71, 41,94, 118,51, 50,121, 65,163, 236,56, 84,222
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.07 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.478/0.860-mean/best, past_thr=0.561-mean: 24,42, 24,57, 36,71, 41,94, 116,49, 50,123, 64,168, 242,55, 84,227
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.04 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.475/0.861-mean/best, past_thr=0.559-mean: 24,41, 23,56, 34,71, 42,97, 120,49, 52,127, 61,173, 235,55, 84,221
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.04 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.474/0.863-mean/best, past_thr=0.557-mean: 22,41, 23,57, 33,69, 43,96, 121,49, 51,132, 60,173, 241,55, 82,220
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.04 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.474/0.863-mean/best, past_thr=0.557-mean: 22,41, 23,57, 33,69, 43,96, 121,49, 51,132, 60,173, 241,55, 82,220
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.01 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.473/0.863-mean/best, past_thr=0.558-mean: 21,41, 24,56, 31,70, 43,94, 121,49, 52,133, 60,173, 240,54, 85,225
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.02 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.472/0.863-mean/best, past_thr=0.556-mean: 21,41, 23,55, 31,68, 42,94, 121,49, 51,133, 60,172, 236,54, 86,228
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.02 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.472/0.863-mean/best, past_thr=0.556-mean: 21,41, 23,55, 31,68, 42,94, 120,49, 51,133, 61,171, 236,54, 86,228
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.12 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.476/0.865-mean/best, past_thr=0.557-mean: 21,40, 23,56, 32,68, 42,98, 115,50, 52,121, 67,163, 232,56, 86,225
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.12 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.477/0.865-mean/best, past_thr=0.558-mean: 21,41, 23,55, 32,68, 42,97, 115,50, 53,121, 67,162, 230,54, 87,225
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.12 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.478/0.865-mean/best, past_thr=0.558-mean: 21,41, 24,55, 32,68, 41,96, 114,50, 53,124, 67,161, 231,55, 86,225
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.11 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.478/0.865-mean/best, past_thr=0.558-mean: 21,41, 23,55, 32,68, 41,96, 114,50, 53,124, 67,161, 231,55, 86,225
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.12 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.478/0.865-mean/best, past_thr=0.558-mean: 21,41, 23,55, 32,68, 41,96, 114,50, 53,124, 67,161, 231,54, 87,225
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.13 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.479/0.865-mean/best, past_thr=0.559-mean: 21,42, 23,55, 32,69, 41,96, 114,50, 53,124, 67,159, 231,54, 87,224
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.14 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.480/0.865-mean/best, past_thr=0.559-mean: 21,42, 23,55, 32,69, 40,95, 113,50, 53,122, 67,157, 231,54, 87,224
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.14 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.480/0.865-mean/best, past_thr=0.559-mean: 21,42, 23,55, 32,68, 40,97, 113,50, 53,120, 68,156, 230,54, 87,224
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.14 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.479/0.865-mean/best, past_thr=0.558-mean: 21,42, 23,54, 31,68, 40,97, 113,50, 53,120, 68,158, 227,54, 86,224
# AutoAnchor: Evolving anchors with Genetic Algorithm: fitness = 0.8654:  20%|█▉        | 197/1000 [00:00<00:00, 1960.24it/s]AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.16 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.479/0.866-mean/best, past_thr=0.557-mean: 21,40, 23,55, 32,66, 41,97, 113,51, 51,122, 68,158, 218,55, 84,222
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.15 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.479/0.866-mean/best, past_thr=0.557-mean: 21,40, 23,54, 32,66, 41,96, 113,51, 52,123, 67,159, 220,55, 83,221
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.15 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.479/0.866-mean/best, past_thr=0.557-mean: 21,40, 23,54, 32,66, 41,96, 113,51, 51,123, 67,158, 222,55, 84,221
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.15 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.479/0.866-mean/best, past_thr=0.557-mean: 21,40, 22,54, 32,67, 41,95, 113,51, 51,121, 66,159, 220,54, 82,223
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.15 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.479/0.866-mean/best, past_thr=0.558-mean: 21,40, 22,54, 32,66, 41,95, 113,51, 51,121, 66,159, 220,54, 82,222
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.15 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.480/0.866-mean/best, past_thr=0.559-mean: 21,40, 23,54, 32,66, 41,95, 113,51, 52,119, 66,158, 221,54, 82,221
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.18 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.481/0.866-mean/best, past_thr=0.558-mean: 21,40, 23,54, 32,66, 41,95, 111,51, 51,119, 66,161, 219,54, 82,221
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.20 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.482/0.866-mean/best, past_thr=0.559-mean: 21,40, 23,54, 32,68, 42,95, 111,51, 51,117, 64,160, 218,54, 82,217
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.19 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.483/0.866-mean/best, past_thr=0.560-mean: 21,41, 23,55, 31,68, 42,95, 112,50, 52,118, 65,160, 215,55, 83,217
# AutoAnchor: Evolving anchors with Genetic Algorithm: fitness = 0.8664:  41%|████▏     | 414/1000 [00:00<00:00, 2069.36it/s]AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.19 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.482/0.866-mean/best, past_thr=0.559-mean: 21,41, 23,55, 31,68, 42,96, 112,51, 52,118, 65,158, 214,54, 83,219
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.19 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.483/0.867-mean/best, past_thr=0.560-mean: 21,41, 23,55, 31,68, 42,96, 112,51, 52,118, 65,157, 215,55, 82,219
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.18 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.484/0.867-mean/best, past_thr=0.561-mean: 21,41, 23,55, 32,68, 42,93, 113,51, 51,117, 63,156, 215,55, 82,220
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.17 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.484/0.867-mean/best, past_thr=0.562-mean: 22,41, 23,55, 31,68, 42,94, 113,51, 52,116, 63,156, 216,55, 82,220
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.19 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.484/0.867-mean/best, past_thr=0.561-mean: 22,41, 23,55, 31,68, 42,93, 112,51, 51,116, 63,157, 213,55, 82,219
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.18 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.484/0.867-mean/best, past_thr=0.561-mean: 22,41, 23,55, 31,69, 42,94, 113,51, 51,116, 63,157, 213,55, 83,219
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.18 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.484/0.867-mean/best, past_thr=0.561-mean: 22,41, 23,55, 31,69, 42,93, 112,51, 51,116, 63,157, 213,55, 83,219
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.21 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.484/0.867-mean/best, past_thr=0.560-mean: 22,41, 23,55, 31,69, 42,94, 112,51, 51,117, 63,157, 213,55, 83,219
# AutoAnchor: Evolving anchors with Genetic Algorithm: fitness = 0.8669:  62%|██████▏   | 621/1000 [00:00<00:00, 1875.77it/s]AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.21 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.484/0.867-mean/best, past_thr=0.560-mean: 22,41, 23,55, 31,69, 42,94, 112,51, 51,117, 63,157, 213,55, 83,219
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.21 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.484/0.867-mean/best, past_thr=0.560-mean: 22,41, 23,55, 31,69, 42,93, 112,51, 51,117, 63,157, 213,55, 83,219
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.21 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.484/0.867-mean/best, past_thr=0.560-mean: 21,41, 23,54, 31,68, 41,93, 112,51, 51,117, 63,158, 213,55, 83,220
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.21 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.484/0.867-mean/best, past_thr=0.560-mean: 21,41, 23,54, 31,68, 41,93, 112,51, 50,117, 63,158, 213,55, 83,219
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.22 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.485/0.867-mean/best, past_thr=0.560-mean: 21,41, 23,55, 31,68, 41,93, 111,51, 50,117, 64,160, 214,55, 83,214
# AutoAnchor: Evolving anchors with Genetic Algorithm: fitness = 0.8672:  83%|████████▎ | 826/1000 [00:00<00:00, 1933.70it/s]AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.22 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.485/0.867-mean/best, past_thr=0.561-mean: 21,41, 23,54, 31,67, 41,93, 111,51, 50,117, 63,160, 212,55, 83,213
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.22 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.485/0.867-mean/best, past_thr=0.561-mean: 21,41, 23,55, 31,67, 41,93, 111,51, 50,118, 63,160, 212,55, 83,213
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.22 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.485/0.867-mean/best, past_thr=0.561-mean: 21,41, 23,55, 31,67, 41,93, 111,51, 50,117, 63,160, 212,55, 83,213
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.22 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.485/0.867-mean/best, past_thr=0.561-mean: 21,41, 23,55, 31,67, 41,93, 111,51, 50,118, 63,160, 212,55, 83,212
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.22 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.485/0.867-mean/best, past_thr=0.561-mean: 21,41, 23,55, 31,67, 41,93, 111,51, 50,117, 63,160, 212,55, 83,212
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.22 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.485/0.867-mean/best, past_thr=0.561-mean: 21,41, 23,55, 31,67, 41,93, 112,51, 49,117, 63,160, 212,55, 83,213
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.23 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.486/0.867-mean/best, past_thr=0.561-mean: 21,41, 23,55, 31,67, 40,93, 112,51, 50,117, 63,160, 213,55, 83,210
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.23 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.486/0.867-mean/best, past_thr=0.561-mean: 21,41, 23,55, 31,67, 40,93, 112,51, 50,117, 63,161, 212,56, 83,210
# AutoAnchor: Evolving anchors with Genetic Algorithm: fitness = 0.8675: 100%|██████████| 1000/1000 [00:00<00:00, 1980.18it/s]
# AutoAnchor: thr=0.25: 1.0000 best possible recall, 7.23 anchors past thr
# AutoAnchor: n=9, img_size=640, metric_all=0.486/0.867-mean/best, past_thr=0.561-mean: 21,41, 23,55, 31,67, 40,93, 112,51, 50,117, 63,161, 212,56, 83,210
# Calculated new anchors:
#  [[     21.384      41.469]
#  [     22.869      55.076]
#  [     31.366       67.35]
#  [     40.227      92.827]
#  [     112.34      50.807]
#  [     50.006      116.61]
#  [     62.811      160.61]
#  [     212.26      55.616]
#  [     82.891      209.91]]

# %%
from utils.general import scale_boxes, non_max_suppression

conf_thres = 0.25  # confidence threshold
iou_thres = 0.45  # NMS IOU threshold
max_det = 1000  # maximum detections per image
classes = None
agnostic_nms = False  # class-agnostic NMS

pred = non_max_suppression(pred, conf_thres, iou_thres, classes, agnostic_nms, max_det=max_det)

# Resize predicted box
scale_boxes()         # see valpy:L285

# [TODO] draw predictions (see detect.py:L178)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 12
#       9 pred = non_max_suppression(pred, conf_thres, iou_thres, classes, agnostic_nms, max_det=max_det)
#      11 # Resize predicted box
# ---> 12 scale_boxes()         # see valpy:L285
#      14 # [TODO] draw predictions (see detect.py:L178)
#
# TypeError: scale_boxes() missing 3 required positional arguments: 'img1_shape', 'boxes', and 'img0_shape'

# %%
pred[0]
# Out:
# tensor([], size=(0, 6))
